-- %%
-- Create Table
CREATE TABLE MarineInsurance
(
    PolicyID INT,
    CustomerName VARCHAR(50),
    VesselName VARCHAR(50),
    CargoType VARCHAR(50),
    PolicyAmount DECIMAL(12,2),
    ClaimAmount DECIMAL(12,2),
    Premium DECIMAL(10,2),
    Port VARCHAR(50),
    PolicyStatus VARCHAR(20),
    PolicyDate DATE
);
--insert data

INSERT INTO MarineInsurance VALUES
(101,'John','Sea Queen','Electronics',250000,50000,5000,'Houston','Active','2024-01-10'),
(102,'David','Ocean Star','Furniture',300000,0,6000,'Miami','Active','2024-01-12'),
(103,'Emily','Blue Wave','Chemicals',500000,150000,9500,'Houston','Claimed','2024-01-15'),
(104,'Robert','Sea King','Vehicles',450000,70000,8500,'Seattle','Active','2024-01-18'),
(105,'Sophia','Marine One','Machinery',600000,200000,11000,'Miami','Claimed','2024-01-20'),
(106,'James','Atlantic','Food',200000,0,4200,'Seattle','Expired','2024-01-22'),
(107,'Olivia','Pacific','Electronics',350000,100000,7000,'Houston','Claimed','2024-01-25'),
(108,'William','Ocean Pearl','Furniture',280000,0,5400,'Miami','Active','2024-01-28');

SELECT * FROM MarineInsurance;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>VesselName</th><th>CargoType</th><th>PolicyAmount</th><th>ClaimAmount</th><th>Premium</th><th>Port</th><th>PolicyStatus</th><th>PolicyDate</th></tr></thead><tbody><tr><td>101</td><td>John</td><td>Sea Queen</td><td>Electronics</td><td>250000.00</td><td>50000.00</td><td>5000.00</td><td>Houston</td><td>Active</td><td>2024-01-10</td></tr><tr><td>102</td><td>David</td><td>Ocean Star</td><td>Furniture</td><td>300000.00</td><td>0.00</td><td>6000.00</td><td>Miami</td><td>Active</td><td>2024-01-12</td></tr><tr><td>103</td><td>Emily</td><td>Blue Wave</td><td>Chemicals</td><td>500000.00</td><td>150000.00</td><td>9500.00</td><td>Houston</td><td>Claimed</td><td>2024-01-15</td></tr><tr><td>104</td><td>Robert</td><td>Sea King</td><td>Vehicles</td><td>450000.00</td><td>70000.00</td><td>8500.00</td><td>Seattle</td><td>Active</td><td>2024-01-18</td></tr><tr><td>105</td><td>Sophia</td><td>Marine One</td><td>Machinery</td><td>600000.00</td><td>200000.00</td><td>11000.00</td><td>Miami</td><td>Claimed</td><td>2024-01-20</td></tr><tr><td>106</td><td>James</td><td>Atlantic</td><td>Food</td><td>200000.00</td><td>0.00</td><td>4200.00</td><td>Seattle</td><td>Expired</td><td>2024-01-22</td></tr><tr><td>107</td><td>Olivia</td><td>Pacific</td><td>Electronics</td><td>350000.00</td><td>100000.00</td><td>7000.00</td><td>Houston</td><td>Claimed</td><td>2024-01-25</td></tr><tr><td>108</td><td>William</td><td>Ocean Pearl</td><td>Furniture</td><td>280000.00</td><td>0.00</td><td>5400.00</td><td>Miami</td><td>Active</td><td>2024-01-28</td></tr></tbody></table></div>

-- %%
-- Q1: Policies with premium greater than average premium

WITH AvgPremium AS
(
    SELECT AVG(Premium) AS Avg_Premium
    FROM MarineInsurance
)

SELECT *
FROM MarineInsurance
WHERE Premium > (SELECT Avg_Premium FROM AvgPremium);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>VesselName</th><th>CargoType</th><th>PolicyAmount</th><th>ClaimAmount</th><th>Premium</th><th>Port</th><th>PolicyStatus</th><th>PolicyDate</th></tr></thead><tbody><tr><td>103</td><td>Emily</td><td>Blue Wave</td><td>Chemicals</td><td>500000.00</td><td>150000.00</td><td>9500.00</td><td>Houston</td><td>Claimed</td><td>2024-01-15</td></tr><tr><td>104</td><td>Robert</td><td>Sea King</td><td>Vehicles</td><td>450000.00</td><td>70000.00</td><td>8500.00</td><td>Seattle</td><td>Active</td><td>2024-01-18</td></tr><tr><td>105</td><td>Sophia</td><td>Marine One</td><td>Machinery</td><td>600000.00</td><td>200000.00</td><td>11000.00</td><td>Miami</td><td>Claimed</td><td>2024-01-20</td></tr></tbody></table></div>

-- %%
-- Q2: Customer(s) having the highest policy amount

WITH MaxPolicy AS
(
    SELECT MAX(PolicyAmount) AS Max_Policy
    FROM MarineInsurance
)

SELECT CustomerName, PolicyAmount
FROM MarineInsurance
WHERE PolicyAmount = (SELECT Max_Policy FROM MaxPolicy);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>PolicyAmount</th></tr></thead><tbody><tr><td>Sophia</td><td>600000.00</td></tr></tbody></table></div>

-- %%
-- Q3: Customer(s) having the highest claim amount

WITH MaxClaim AS
(
    SELECT MAX(ClaimAmount) AS Max_Claim
    FROM MarineInsurance
)

SELECT CustomerName, ClaimAmount
FROM MarineInsurance
WHERE ClaimAmount = (SELECT Max_Claim FROM MaxClaim);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>ClaimAmount</th></tr></thead><tbody><tr><td>Sophia</td><td>200000.00</td></tr></tbody></table></div>

-- %%
-- Q4: Total premium collected from each port

WITH PortPremium AS
(
    SELECT Port,
           SUM(Premium) AS Total_Premium
    FROM MarineInsurance
    GROUP BY Port
)

SELECT *
FROM PortPremium;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Port</th><th>Total_Premium</th></tr></thead><tbody><tr><td>Houston</td><td>21500.00</td></tr><tr><td>Miami</td><td>22400.00</td></tr><tr><td>Seattle</td><td>12700.00</td></tr></tbody></table></div>

-- %%
-- Q5: Ports having total premium greater than 15000

WITH PortPremium AS
(
    SELECT Port,
           SUM(Premium) AS Total_Premium
    FROM MarineInsurance
    GROUP BY Port
)

SELECT *
FROM PortPremium
WHERE Total_Premium > 15000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Port</th><th>Total_Premium</th></tr></thead><tbody><tr><td>Houston</td><td>21500.00</td></tr><tr><td>Miami</td><td>22400.00</td></tr></tbody></table></div>

-- %%
-- Q6: Total policy amount for each cargo type

WITH CargoPolicy AS
(
    SELECT CargoType,
           SUM(PolicyAmount) AS Total_Policy
    FROM MarineInsurance
    GROUP BY CargoType
)

SELECT *
FROM CargoPolicy;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CargoType</th><th>Total_Policy</th></tr></thead><tbody><tr><td>Electronics</td><td>600000.00</td></tr><tr><td>Furniture</td><td>580000.00</td></tr><tr><td>Chemicals</td><td>500000.00</td></tr><tr><td>Vehicles</td><td>450000.00</td></tr><tr><td>Machinery</td><td>600000.00</td></tr><tr><td>Food</td><td>200000.00</td></tr></tbody></table></div>

-- %%
-- Q7: Average policy amount for each port

WITH AvgPolicy AS
(
    SELECT Port,
           AVG(PolicyAmount) AS Avg_Policy
    FROM MarineInsurance
    GROUP BY Port
)

SELECT *
FROM AvgPolicy;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Port</th><th>Avg_Policy</th></tr></thead><tbody><tr><td>Houston</td><td>366666.666667</td></tr><tr><td>Miami</td><td>393333.333333</td></tr><tr><td>Seattle</td><td>325000.000000</td></tr></tbody></table></div>

-- %%
-- Q8: Policies with policy amount greater than overall average

WITH AvgPolicy AS
(
    SELECT AVG(PolicyAmount) AS Avg_Policy
    FROM MarineInsurance
)

SELECT *
FROM MarineInsurance
WHERE PolicyAmount > (SELECT Avg_Policy FROM AvgPolicy);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>VesselName</th><th>CargoType</th><th>PolicyAmount</th><th>ClaimAmount</th><th>Premium</th><th>Port</th><th>PolicyStatus</th><th>PolicyDate</th></tr></thead><tbody><tr><td>103</td><td>Emily</td><td>Blue Wave</td><td>Chemicals</td><td>500000.00</td><td>150000.00</td><td>9500.00</td><td>Houston</td><td>Claimed</td><td>2024-01-15</td></tr><tr><td>104</td><td>Robert</td><td>Sea King</td><td>Vehicles</td><td>450000.00</td><td>70000.00</td><td>8500.00</td><td>Seattle</td><td>Active</td><td>2024-01-18</td></tr><tr><td>105</td><td>Sophia</td><td>Marine One</td><td>Machinery</td><td>600000.00</td><td>200000.00</td><td>11000.00</td><td>Miami</td><td>Claimed</td><td>2024-01-20</td></tr></tbody></table></div>

-- %%
-- Q9: Port having the highest total policy amount

WITH PortPolicy AS
(
    SELECT Port,
           SUM(PolicyAmount) AS Total_Policy
    FROM MarineInsurance
    GROUP BY Port
),
MaxPolicy AS
(
    SELECT MAX(Total_Policy) AS Max_Total
    FROM PortPolicy
)

SELECT *
FROM PortPolicy
WHERE Total_Policy = (SELECT Max_Total FROM MaxPolicy);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Port</th><th>Total_Policy</th></tr></thead><tbody><tr><td>Miami</td><td>1180000.00</td></tr></tbody></table></div>

-- %%
-- Q10: Policies with claim amount greater than average claim amount

WITH AvgClaim AS
(
    SELECT AVG(ClaimAmount) AS Avg_Claim
    FROM MarineInsurance
)

SELECT *
FROM MarineInsurance
WHERE ClaimAmount > (SELECT Avg_Claim FROM AvgClaim);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>VesselName</th><th>CargoType</th><th>PolicyAmount</th><th>ClaimAmount</th><th>Premium</th><th>Port</th><th>PolicyStatus</th><th>PolicyDate</th></tr></thead><tbody><tr><td>103</td><td>Emily</td><td>Blue Wave</td><td>Chemicals</td><td>500000.00</td><td>150000.00</td><td>9500.00</td><td>Houston</td><td>Claimed</td><td>2024-01-15</td></tr><tr><td>105</td><td>Sophia</td><td>Marine One</td><td>Machinery</td><td>600000.00</td><td>200000.00</td><td>11000.00</td><td>Miami</td><td>Claimed</td><td>2024-01-20</td></tr><tr><td>107</td><td>Olivia</td><td>Pacific</td><td>Electronics</td><td>350000.00</td><td>100000.00</td><td>7000.00</td><td>Houston</td><td>Claimed</td><td>2024-01-25</td></tr></tbody></table></div>

-- %%
-- Q11: Policies having policy amount greater than their port average

WITH PortAverage AS
(
    SELECT Port,
           AVG(PolicyAmount) AS Avg_Policy
    FROM MarineInsurance
    GROUP BY Port
)

SELECT M.*
FROM MarineInsurance M
JOIN PortAverage P
ON M.Port = P.Port
WHERE M.PolicyAmount > P.Avg_Policy;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>VesselName</th><th>CargoType</th><th>PolicyAmount</th><th>ClaimAmount</th><th>Premium</th><th>Port</th><th>PolicyStatus</th><th>PolicyDate</th></tr></thead><tbody><tr><td>103</td><td>Emily</td><td>Blue Wave</td><td>Chemicals</td><td>500000.00</td><td>150000.00</td><td>9500.00</td><td>Houston</td><td>Claimed</td><td>2024-01-15</td></tr><tr><td>104</td><td>Robert</td><td>Sea King</td><td>Vehicles</td><td>450000.00</td><td>70000.00</td><td>8500.00</td><td>Seattle</td><td>Active</td><td>2024-01-18</td></tr><tr><td>105</td><td>Sophia</td><td>Marine One</td><td>Machinery</td><td>600000.00</td><td>200000.00</td><td>11000.00</td><td>Miami</td><td>Claimed</td><td>2024-01-20</td></tr></tbody></table></div>

-- %%
-- Q12: Cargo types with total claim amount greater than 100000

WITH CargoClaim AS
(
    SELECT CargoType,
           SUM(ClaimAmount) AS Total_Claim
    FROM MarineInsurance
    GROUP BY CargoType
)

SELECT *
FROM CargoClaim
WHERE Total_Claim > 100000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CargoType</th><th>Total_Claim</th></tr></thead><tbody><tr><td>Electronics</td><td>150000.00</td></tr><tr><td>Chemicals</td><td>150000.00</td></tr><tr><td>Machinery</td><td>200000.00</td></tr></tbody></table></div>

-- %%
-- Q13: Customers paying premium greater than their port average

WITH PortAverage AS
(
    SELECT Port,
           AVG(Premium) AS Avg_Premium
    FROM MarineInsurance
    GROUP BY Port
)

SELECT M.CustomerName,
       M.Port,
       M.Premium
FROM MarineInsurance M
JOIN PortAverage P
ON M.Port = P.Port
WHERE M.Premium > P.Avg_Premium;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>Port</th><th>Premium</th></tr></thead><tbody><tr><td>Emily</td><td>Houston</td><td>9500.00</td></tr><tr><td>Robert</td><td>Seattle</td><td>8500.00</td></tr><tr><td>Sophia</td><td>Miami</td><td>11000.00</td></tr></tbody></table></div>

-- %%
-- Q14: Policies contributing more than 25% of their port's total premium

WITH PortPremium AS
(
    SELECT Port,
           SUM(Premium) AS Total_Premium
    FROM MarineInsurance
    GROUP BY Port
)

SELECT M.PolicyID,
       M.CustomerName,
       M.Port,
       M.Premium
FROM MarineInsurance M
JOIN PortPremium P
ON M.Port = P.Port
WHERE M.Premium > (0.25 * P.Total_Premium);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PolicyID</th><th>CustomerName</th><th>Port</th><th>Premium</th></tr></thead><tbody><tr><td>102</td><td>David</td><td>Miami</td><td>6000.00</td></tr><tr><td>103</td><td>Emily</td><td>Houston</td><td>9500.00</td></tr><tr><td>104</td><td>Robert</td><td>Seattle</td><td>8500.00</td></tr><tr><td>105</td><td>Sophia</td><td>Miami</td><td>11000.00</td></tr><tr><td>106</td><td>James</td><td>Seattle</td><td>4200.00</td></tr><tr><td>107</td><td>Olivia</td><td>Houston</td><td>7000.00</td></tr></tbody></table></div>

-- %%
-- Q15: Total premium, total claim amount, and total policy amount for each port

WITH PortSummary AS
(
    SELECT Port,
           SUM(Premium) AS Total_Premium,
           SUM(ClaimAmount) AS Total_Claim,
           SUM(PolicyAmount) AS Total_Policy
    FROM MarineInsurance
    GROUP BY Port
)

SELECT *
FROM PortSummary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Port</th><th>Total_Premium</th><th>Total_Claim</th><th>Total_Policy</th></tr></thead><tbody><tr><td>Houston</td><td>21500.00</td><td>300000.00</td><td>1100000.00</td></tr><tr><td>Miami</td><td>22400.00</td><td>200000.00</td><td>1180000.00</td></tr><tr><td>Seattle</td><td>12700.00</td><td>70000.00</td><td>650000.00</td></tr></tbody></table></div>
